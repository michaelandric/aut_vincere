# %%
import numpy as np
import pandas as pd
import warnings
import os

# %% [markdown]
# ### Establish connection to the postgres db:

# %%
import psycopg2
conn = psycopg2.connect("dbname=bball user=andric")
cur = conn.cursor()

# %% [markdown]
# Below two cells provide example for necessary "rollback" when twice a call is made on a bad query.
#
# Postgres gives the `current transaction is aborted, commands ignored until of transaction block`
# when this happens

# %%
# quer = "select * from playerdata WHERE season='2013';"
#cur.execute(quer)
# quer_out = cur.fetchall()
# pd.DataFrame(quer_out)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-21-a766f91c9705> in <module>()
#       1 quer = "select * from playerdata WHERE season='2013';"
# ----> 2 cur.execute(quer)
#       3 quer_out = cur.fetchall()
#       4 pd.DataFrame(quer_out)
#
# InternalError: current transaction is aborted, commands ignored until end of transaction block

# %%
# conn.rollback()

# %% [markdown]
# ### This query grabs the column names from the db table

# %%
quer = "select column_name from information_schema.columns \
where table_schema = 'public' and table_name = 'playerdata';"
cur.execute(quer)
quer_out = cur.fetchall()
headers = [hh[0] for hh in quer_out]

# %% [markdown]
# ### Now query to grab data.

# %%
# quer = "select * from playerdata where season='2013';"
# cur.execute(quer)
# data_quer_out = cur.fetchall()
# pd.DataFrame(data_quer_out).shape
# df13 = pd.DataFrame(data_quer_out, columns=headers).iloc[:, 1:]
# Out:
# (452, 29)

# %%
def get_season_data(year):
    """Get dataframe from query.
    Build list of them.
    """
    quer = "select * from playerdata where season='%s';" % year
    cur.execute(quer)
    data_quer_out = cur.fetchall()
    return data_quer_out


df_list = []
for yr in range(2013, 2017):
    df_list.append(pd.DataFrame(
            get_season_data(yr), columns=headers).iloc[:, 1:])

# %%
df13, df14, df15, df16 = df_list
players_intersect = list(set(df16.player).intersection(
        df15.player).intersection(
        df14.player).intersection(
        df13.player))

# %% [markdown]
# #### get players common to all four data frames:

# %%
def keepers(dataframe, player_list):
    return dataframe.iloc[np.where(np.in1d(dataframe.player,
                                           player_list)==True)[0], :]

# %%
keepers_df_list = []
for df in df_list:
    keepers_df_list.append(
        keepers(df, players_intersect).sort_values('player'))

df13, df14, df15, df16 = keepers_df_list

# %% [markdown]
# #### Now tables are sorted with same players.

# %% [markdown]
# ### Build some models

# %%
from sklearn.linear_model import LinearRegression

# %%
df13.columns
# Out:
# Index(['player', 'season', 'age', 'g', 'gs', 'mp', 'fg', 'fga', 'fgp', '3p',
#        '3pa', '3pp', '2p', '2pa', '2pp', 'efgp', 'ft', 'fta', 'ftp', 'orb',
#        'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'psg'],
#       dtype='object')

# %%
X = np.column_stack([df15.fgp, df15.ftp, df15.loc[:, "3pp"]])
y = df16.psg.values
linr = LinearRegression()
linr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Explain PS/G:')
for n in np.argsort(linr.coef_)[::-1]:
    print('%.4f' % linr.coef_[n])
# Out:
# Explain PS/G:
# 9.0875
# 1.7279
# -3.3311

# %%
print([i for i, pp in enumerate(df16.player) if pp == 'LeBron James'])
print([i for i, pp in enumerate(df16.player) if pp == 'Patrick Beverley'])
print([i for i, pp in enumerate(df16.player) if pp == 'Timofey Mozgov'])
print([i for i, pp in enumerate(df16.player) if pp == 'Kevin Durant'])
print([i for i, pp in enumerate(df16.player) if pp == 'Kemba Walker'])
# Out:
# [154]
# [195]
# [233]
# [136]
# [131]

# %%
print('LeBron: %.4f' % linr.predict(df16.iloc[154, :][['fgp', 'ftp', 'efgp', 'psg']].values.reshape(1, -1)))
print('Pat Beverley: %.4f' % linr.predict(df16.iloc[195, :][['fgp', 'ftp', 'efgp', 'psg']].values.reshape(1, -1)))
print('Mozgov: %.4f' % linr.predict(df16.iloc[233, :][['fgp', 'ftp', 'efgp', 'psg']].values.reshape(1, -1)))
print('Durant: %.4f' % linr.predict(df16.iloc[136, :][['fgp', 'ftp', 'efgp', 'psg']].values.reshape(1, -1)))
print('Kemba: %.4f' % linr.predict(df16.iloc[131, :][['fgp', 'ftp', 'efgp', 'psg']].values.reshape(1, -1)))
# Out:
# LeBron: 22.9455
# Pat Beverley: 9.9372
# Mozgov: 6.0021
# Durant: 25.7573
# Kemba: 19.2956

# %%
print('LeBron: %.4f' % linr.predict(df16.iloc[154, :][['fgp', 'ftp', '3pp']].values.reshape(1, -1)))
print('Pat Beverley: %.4f' % linr.predict(df16.iloc[195, :][['fgp', 'ftp', '3pp']].values.reshape(1, -1)))
print('Mozgov: %.4f' % linr.predict(df16.iloc[233, :][['fgp', 'ftp', '3pp']].values.reshape(1, -1)))
print('Durant: %.4f' % linr.predict(df16.iloc[136, :][['fgp', 'ftp', '3pp']].values.reshape(1, -1)))
print('Kemba: %.4f' % linr.predict(df16.iloc[131, :][['fgp', 'ftp', '3pp']].values.reshape(1, -1)))
# Out:
# LeBron: 10.1051
# Pat Beverley: 11.1339
# Mozgov: 8.4208
# Durant: 11.1525
# Kemba: 11.1788

# %% [markdown]
# ## Plot features

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
sns.pairplot(df13.iloc[:, 3:])

# %%
df13.columns[3:]
# Out:
# Index(['g', 'gs', 'mp', 'fg', 'fga', 'fgp', '3p', '3pa', '3pp', '2p', '2pa',
#        '2pp', 'efgp', 'ft', 'fta', 'ftp', 'orb', 'drb', 'trb', 'ast', 'stl',
#        'blk', 'tov', 'pf', 'psg'],
#       dtype='object')

# %%
sns.jointplot(x='drb', y='psg', data=df13)

# %%
df13.corr()
# Out:
#            age         g        gs        mp        fg       fga       fgp  \
# age   1.000000  0.078156  0.005800  0.126351  0.127004  0.116413  0.075614
# g     0.078156  1.000000  0.557615  0.547672  0.448260  0.433312  0.195372
# gs    0.005800  0.557615  1.000000  0.797097  0.708528  0.676498  0.154048
# ast   0.082999  1.000000  0.735195 -0.127026 -0.022840  0.268349  0.631417
# stl   0.268017  0.735195  1.000000  0.025572 -0.002900  0.382413  0.667188
# blk   0.646873 -0.127026  0.025572  1.000000 -0.024870  0.471868  0.255477
# tov   0.008098 -0.022840 -0.002900 -0.024870  1.000000 -0.027150  0.004610
# pf    0.613046  0.268349  0.382413  0.471868 -0.027150  1.000000  0.476386
# psg   0.511677  0.631417  0.667188  0.255477  0.004610  0.476386  1.000000
#
# [26 rows x 26 columns]

# %%
df13.corr()['psg'][np.argsort(df13.corr()['psg'])][::-1][2:8]
# Out:
# fga    0.978008
# 2pa    0.889459
# mp     0.889072
# ft     0.883858
# 2p     0.876684
# fta    0.864628
# Name: psg, dtype: float64

# %%
df14.corr()['psg'][np.argsort(df14.corr()['psg'])][::-1][2:8]
# Out:
# fga    0.976806
# ft     0.896381
# fta    0.877399
# 2pa    0.874737
# mp     0.873380
# 2p     0.867874
# Name: psg, dtype: float64

# %%
df15.corr()['psg'][np.argsort(df15.corr()['psg'])][::-1][2:8]
# Out:
# fga    0.978631
# ft     0.896732
# 2pa    0.879672
# fta    0.873322
# 2p     0.868294
# mp     0.867916
# Name: psg, dtype: float64

# %%
X = np.column_stack([df15.fga, df15.ft, df15.loc[:, "2pa"], df15.mp])
y = df15.psg.values
linr = LinearRegression()
linr.fit(X, y)
print('Explain PS/G:')
for n in np.argsort(linr.coef_)[::-1]:
    print('%.4f' % linr.coef_[n])
# Out:
# Explain PS/G:
# 1.0711
# 0.9363
# 0.0498
# -0.0643

# %%
print('LeBron: %.4f' % linr.predict(df16.iloc[154, :][['fga', 'ft', '2pa']].values.reshape(1, -1)))
print('Kemba: %.4f' % linr.predict(df16.iloc[131, :][['fga', 'ft', '2pa']].values.reshape(1, -1)))
print('Mozgov: %.4f' % linr.predict(df16.iloc[233, :][['fga', 'ft', '2pa']].values.reshape(1, -1)))
# Out:
# LeBron: 23.0726
# Kemba: 21.0353
# Mozgov: 5.5556

# %%
from sklearn.cross_validation import train_test_split

# %%
X = np.column_stack([df15.fga, df15.ft])
y = df15.psg.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
linr = LinearRegression()
linr.fit(X_train, y_train)
y_train_pred = linr.predict(X_train)
y_test_pred = linr.predict(X_test)

# %%
plt.scatter(y_train_pred, y_train_pred - y_train, c='blue', marker='o', label='Training data')
plt.scatter(y_test_pred, y_test_pred - y_test, c='lightgreen', marker='s', label='Test data')
plt.xlabel('Predicted vals')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0, xmin=-10, xmax=50, lw=2, color='red')
plt.xlim([-10, 50])

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# [df15.fga, df15.ft, df15.loc[:, "2pa"], df15.mp]
print('MSE train: %.3f, test: %.3f' % (
        mean_squared_error(y_train, y_train_pred), mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test %.3f' % (
        r2_score(y_train, y_train_pred), r2_score(y_test, y_test_pred)))
# Out:
# MSE train: 0.559, test: 0.890
# R^2 train: 0.981, test 0.971

# %%
# [df15.fga, df15.ft, df15.loc[:, "2pa"]]
print('MSE train: %.3f, test: %.3f' % (
        mean_squared_error(y_train, y_train_pred), mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test %.3f' % (
        r2_score(y_train, y_train_pred), r2_score(y_test, y_test_pred)))
# Out:
# MSE train: 0.693, test: 0.485
# R^2 train: 0.978, test 0.980

# %%
# [df15.fga, df15.ft]
print('MSE train: %.3f, test: %.3f' % (
        mean_squared_error(y_train, y_train_pred), mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.3f, test %.3f' % (
        r2_score(y_train, y_train_pred), r2_score(y_test, y_test_pred)))
# Out:
# MSE train: 0.616, test: 0.879
# R^2 train: 0.979, test 0.972
